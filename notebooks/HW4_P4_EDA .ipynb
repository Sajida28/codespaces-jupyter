# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
# %pip install sweetviz
import sweetviz as sv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Loading data in pandas data frame
df = pd.read_csv("/workspaces/codespaces-jupyter/data/titanic")
#printing first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
for column in df.columns:
    plt.figure(figsize =(10,5))

# %%
#Conditional statemnets according to data types 
#plotting the Categorical and numerical data accordingly
if df["Sex"].dtype == 'object':
    sns.countplot(y=df["Sex"])
    plt.title('BarChart of Sex')
else:
    sns.histplot(df['Age'], kde=True)
    plt.title('Histogram of Age')
    print('Max:' , df['Age'].max())
    print('Min:', df['Age'].min())
    print('Mean:', df['Age'].mean())
    print('Median:', df['Age'].median())
    print('Std:', df['Age'].sd())
    plt.show()

# %%
data = sns.load_dataset('titanic')

# %%
eda =sv.analyze(data)
eda.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
sns.pairplot(data = data, hue = 'survived')

# %%
sns.boxplot(data = data.select_dtypes(include=['float64','int64']))
plt.xticks(rotation = 45)
plt.title('Boxplot of Numerical Vraibales')
# Out:
# Text(0.5, 1.0, 'Boxplot of Numerical Vraibales')

# %%
Crosstabs = pd.crosstab(data['alone'], data['survived'])
Crosstabs
# Out:
# survived    0    1
# alone
# False     175  179
# True      374  163

# %%
sns.heatmap(Crosstabs, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: xlabel='survived', ylabel='alone'>

# %%
Crosstabs1 = pd.crosstab(data['class'], data['survived'])
Crosstabs1
# Out:
# survived    0    1
# class
# First      80  136
# Second     97   87
# Third     372  119

# %%
sns.heatmap(Crosstabs1, annot = True, cmap = 'crest' )
# Out:
# <Axes: xlabel='survived', ylabel='class'>

# %%
sns.pairplot(data, hue ='class')

# %%
sns.pairplot(data, hue ='alone')

# %%
sns.histplot(data = data, bins=10)
# Out:
# <Axes: ylabel='Count'>
